# %% [markdown]
# # Fig. 1a

# %%
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
axes = [8, 8, 8]
data = np.ones(axes, dtype=bool)
alpha = 0.8
colors = np.empty(axes + [4], dtype=np.float32)

# Ctx/HC
colors[0][[0]] = [1, 1, 0, alpha]  
colors[0][[1]] = [0.9882352941176471, 0.8196078431372549, 0.16470588235294117, alpha]  
colors[0][[2]] = [0.9372549019607843, 0.9921568627450981, 0.37254901960784315, alpha]  
colors[0][[3]] = [0.996078431372549, 0.8627450980392157, 0.33725490196078434, alpha] 
colors[0][[4]] = [0.9882352941176471, 0.8862745098039215, 0.0196078431372549, alpha] 
colors[0][[5]] = [1.0, 0.8274509803921568, 0.0, alpha]  
colors[0][[6]] = [0.9725490196078431, 0.8705882352941177, 0.49411764705882355, alpha] 
colors[0][[7]] = [1.0, 0.9490196078431372, 0.0, alpha] 

# Hypopit
colors[1][[0]] = [0.23137254901960785, 0.6901960784313725, 0.25882352941176473, alpha]  
colors[1][[1]] = [0.0392156862745098, 0.4, 0.13725490196078433, alpha]  
colors[1][[2]] = [0.611764705882353, 0.7529411764705882, 0.5098039215686274, alpha]  
colors[1][[3]] = [0.43529411764705883, 0.5058823529411764, 0.2196078431372549, alpha] 
colors[1][[4]] = [0.7803921568627451, 0.9176470588235294, 0.27058823529411763, alpha] 
colors[1][[5]] = [0.25098039215686274, 0.43529411764705883, 0.30196078431372547, alpha]  
colors[1][[6]] = [0.03137254901960784, 0.6549019607843137, 0.4196078431372549, alpha] 
colors[1][[7]] = [0.3058823529411765, 0.47843137254901963, 0.25882352941176473, alpha] 

# Heart
colors[2][[0]] = [0.6980392156862745, 0.0, 0.9294117647058824, alpha]  
colors[2][[1]] = [0.7058823529411765, 0.21568627450980393, 0.3333333333333333, alpha]  
colors[2][[2]] = [0.47058823529411764, 0.2901960784313726, 0.5176470588235295, alpha]  
colors[2][[3]] = [0.7725490196078432, 0.29411764705882354, 0.5411764705882353, alpha] 
colors[2][[4]] = [0.8901960784313725, 0.6274509803921569, 0.9647058823529412, alpha] 
colors[2][[5]] = [0.6901960784313725, 0.4117647058823529, 0.9333333333333333, alpha]  
colors[2][[6]] = [0.7098039215686275, 0.3764705882352941, 0.8117647058823529, alpha] 
colors[2][[7]] = [0.5607843137254902, 0.0, 1.0, alpha] 

# Gonads
colors[3][0] = [0.0, 0.7490196078431373, 0.7490196078431373, alpha]
colors[3][1] = [0.00784313725490196, 0.8784313725490196, 0.9058823529411765, alpha]
colors[3][2] = [0.4392156862745098, 0.8431372549019608, 0.8117647058823529, alpha]  
colors[3][3] = [0.5686274509803921, 0.9764705882352941, 1.0, alpha]  
colors[3][4] = [0.2823529411764706, 0.8313725490196079, 0.8, alpha]  
colors[3][5] = [0.3215686274509804, 0.8941176470588236, 0.8627450980392157, alpha]  
colors[3][6] = [0.4980392156862745, 0.996078431372549, 0.996078431372549, alpha]  
colors[3][7] = [0.0, 0.4470588235294118, 0.5019607843137255, alpha]  

# Adrenal
colors[4][[0]] = [0.49411764705882355, 0.2823529411764706, 0.0, alpha]  
colors[4][[1]] = [0.2901960784313726, 0.22745098039215686, 0.15294117647058825, alpha]  
colors[4][[2]] = [0.3803921568627451, 0.16470588235294117, 0.07058823529411765, alpha]  
colors[4][[3]] = [0.22745098039215686, 0.12156862745098039, 0.01568627450980392, alpha] 
colors[4][[4]] = [0.49411764705882355, 0.28627450980392155, 0.10588235294117647, alpha] 
colors[4][[5]] = [0.21568627450980393, 0.13725490196078433, 0.0784313725490196, alpha]  
colors[4][[6]] = [0.596078431372549, 0.47843137254901963, 0.3137254901960784, alpha] 
colors[4][[7]] = [0.16470588235294117, 0.09019607843137255, 0.0, alpha] 

# Gastroc
colors[5][[0]] = [0.9882352941176471, 0.050980392156862744, 0.7490196078431373, alpha]  
colors[5][[1]] = [0.8784313725490196, 0.058823529411764705, 0.3803921568627451, alpha]  
colors[5][[2]] = [0.996078431372549, 0.43529411764705883, 0.9921568627450981, alpha]  
colors[5][[3]] = [0.8745098039215686, 0.43137254901960786, 0.6313725490196078, alpha] 
colors[5][[4]] = [1.0, 0.0, 0.5647058823529412, alpha] 
colors[5][[5]] = [1.0, 0.396078431372549, 0.796078431372549, alpha]  
colors[5][[6]] = [1.0, 0.4117647058823529, 0.7019607843137254, alpha] 
colors[5][[7]] = [1.0, 0.00392156862745098, 0.996078431372549, alpha] 

# Kidney
colors[6][[0]] = [0.8313725490196079, 0.00784313725490196, 0.0, alpha]  
colors[6][[1]] = [0.9803921568627451, 0.5058823529411764, 0.44313725490196076, alpha]  
colors[6][[2]] = [1.0, 0.1411764705882353, 0.0, alpha]  
colors[6][[3]] = [0.4823529411764706, 0.043137254901960784, 0.00392156862745098, alpha] 
colors[6][[4]] = [0.9294117647058824, 0.15294117647058825, 0.2196078431372549, alpha] 
colors[6][[5]] = [0.803921568627451, 0.3607843137254902, 0.3607843137254902, alpha]  
colors[6][[6]] = [0.7647058823529411, 0.09803921568627451, 0.023529411764705882, alpha] 
colors[6][[7]] = [0.6980392156862745, 0.13725490196078433, 0.12549019607843137, alpha] 

# Liver
colors[7][[0]] = [0.9882352941176471, 0.4, 0.0, alpha]  
colors[7][[1]] = [0.7058823529411765, 0.40784313725490196, 0.16470588235294117, alpha]  
colors[7][[2]] = [0.9372549019607843, 0.4470588235294118, 0.08235294117647059, alpha]  
colors[7][[3]] = [0.9921568627450981, 0.41568627450980394, 0.00784313725490196, alpha] 
colors[7][[4]] = [0.9372549019607843, 0.5098039215686274, 0.050980392156862744, alpha] 
colors[7][[5]] = [0.6980392156862745, 0.33725490196078434, 0.054901960784313725, alpha]  
colors[7][[6]] = [0.803921568627451, 0.4627450980392157, 0.13333333333333333, alpha] 
colors[7][[7]] = [0.984313725490196, 0.5019607843137255, 0.1607843137254902, alpha]

# %%
# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
fig.set_size_inches(11, 11)

ax.voxels(data, facecolors=colors, edgecolors='grey')

ax.set_xticks(np.arange(0, 8, 1))
ax.set_xticklabels([])  

ax.set_yticks(np.arange(0, 9, 1))
ax.set_yticklabels([]) 

ax.set_zticks(np.arange(0, 8, 1))
ax.set_zticklabels([])  

plt.savefig('../fig1/cube.png', bbox_inches='tight', dpi=300)

plt.show()

# %% [markdown]
# # Fig. 1d

# %%
import marsilea as ma
import marsilea.plotter as mp
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import decoupler as dc
import scanpy as sc
import anndata as ad
import scipy as sp
import scanpy as sc
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# ## Pseudobulking code
# Done on HPC

# %%
# tissues = ["Gastrocnemius", 
#            "Heart", 
#            "Adrenal", 
#            "GonadsFemale",
#            "GonadsMale",
#            "CortexHippocampus",
#            "DiencephalonPituitary",
#            "Liver",
#            "Kidney"
# ]

# for tissue in tissues:
#     print(f'Reading in {tissue} adata...', flush = True)
#     file = f'/share/crsp/lab/seyedam/share/igvf_pipeline/IGVF_analysis/cellbender_tissues/annotated/{tissue}_annotated.h5ad'

#     adata = sc.read_h5ad(file) 
#     adata = adata[adata.obs['subtype'] != 'low quality'].copy()
    
#     print(f'Pseudobulking {tissue}...', flush = True)
#     pbdata = dc.get_pseudobulk(adata,
#                                sample_col="lab_sample_id", 
#                                groups_col=None,
#                                layer='cellbender_counts',
#                                mode='sum',
#                                skip_checks=True,
#                                min_cells=10,
#                                min_counts=1000)
#     pbdata.obs = pbdata.obs.applymap(str)
#     pbdata.write_h5ad(f'/share/crsp/lab/seyedam/share/igvf_pipeline/IGVF_analysis/cellbender_tissues/pseudobulk/sample_pseudobulk/{tissue}_sample_pseudobulk.h5ad')

# %% [markdown]
# ## Read in pseudobulk adatas

# %%
tissues = ["Gastrocnemius", 
           "Heart", 
           "Adrenal", 
           "GonadsFemale",
           "GonadsMale",
           "CortexHippocampus",
           "DiencephalonPituitary",
           "Liver",
           "Kidney"
]

pdata_list = []

for tissue in tissues:
    pdata = sc.read(f'/share/crsp/lab/seyedam/share/igvf_pipeline/IGVF_analysis/cellbender_tissues/pseudobulk/sample_pseudobulk/{tissue}_sample_pseudobulk.h5ad')
    pdata_list.append(pdata)

my_pdata = sc.AnnData.concatenate(*pdata_list, index_unique = None)
genotype_order = ["AJ", "B6J", "129S1J", "NODJ", "NZOJ", "CASTJ", "PWKJ", "WSBJ"]
my_pdata.obs['Genotype'] = pd.Categorical(my_pdata.obs['Genotype'], categories=genotype_order, ordered=True)
# Out:
# /opt/apps/python/3.8.0/lib/python3.8/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /opt/apps/python/3.8.0/lib/python3.8/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# ...

# %% [markdown]
# ## Normalize, scale, and compute PCA
# Using all genes, not just HVGs

# %%
# not sure why.... but save raw counts as layer and then put it back later...
my_pdata.layers['counts'] = my_pdata.X.copy()

sc.pp.normalize_total(my_pdata, target_sum=1e6) # rpm
sc.pp.log1p(my_pdata)
sc.tl.pca(my_pdata, svd_solver='arpack', use_highly_variable = False)

# Return raw counts to X
dc.swap_layer(my_pdata, 'counts', X_layer_key=None, inplace=True)

# %% [markdown]
# ## Extract PCA df from adata

# %%
df = pd.DataFrame(my_pdata.obsm["X_pca"])
meta  = my_pdata.obs
df.set_index(meta['lab_sample_id'], inplace=True)
merged_df = pd.merge(df, meta, left_index=True, right_on='lab_sample_id')

pca_loadings = pd.DataFrame(my_pdata.varm["PCs"], index=my_pdata.var_names) # for later

# %% [markdown]
# ## Plot PCA

# %%
geno_palette = ['#DA9CC1', '#F4C245', '#C0BFBF', '#55AF5B', '#4F6EAF', '#52A5DB', '#D83026', '#683C91']
plt.figure(figsize=(5, 5.3), dpi = 200)

legend_order = ['Gastrocnemius', 
                'Liver', 
                'Kidney', 
                'GonadsFemale', 
                'GonadsMale', 
                'CortexHippocampus', 
                'DiencephalonPituitary', 
                'Adrenal', 
                'Heart']

markers_dict = {'Female': 'X', 'Male': 'o'}

sns.scatterplot(x=merged_df.iloc[:, 0], y=merged_df.iloc[:, 1], 
                hue=merged_df['Tissue'], 
                style=merged_df['Sex'], 
                markers=markers_dict, 
                s=80, 
                palette=["#ff6bb7",
                         "#f15922",
                         "#cf1e1a",
                         "#66e7e7",
                         "#1cbaba",
                         "#e9aa01",
                         "#028350",
                         "#a47c4c",
                         "#9c4a9b",
                         ],
                hue_order=legend_order,
                linewidth=0.2) 

plt.title(f'Pseudobulk PCA', fontsize=15)

plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(False)
pc1 = my_pdata.uns["pca"]["variance_ratio"][0]
pc2 = my_pdata.uns["pca"]["variance_ratio"][1]
plt.xlabel(f"PC1 ({pc1:.2%})", fontsize=16)
plt.ylabel(f"PC2 ({pc2:.2%})", fontsize=16)

plt.savefig('../fig1/pseudobulk_sample_pca_color_tissues_pc1_pc2.png',bbox_inches='tight', dpi=300)

plt.show()

# %% [markdown]
# ## Extra -- 3D pca

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))  # Adjust the figure size
ax = fig.add_subplot(111, projection='3d')

palette=["#FF69B4",
         "#AF7AC5",
         "#8B4513",
         "#2FE3E5",
         "#00B7B8",
         "#F8C471",
         "#27AE60",
         "#F15922",
         "#CF1E1A",
         
         ]

# Separate data by sex
male_data = merged_df[merged_df['Sex'] == 'Male']
female_data = merged_df[merged_df['Sex'] == 'Female']

# Scatter plot for male data
ax.scatter(xs=male_data.iloc[:, 0], 
           ys=male_data.iloc[:, 1], 
           zs=male_data.iloc[:, 2],  
           c=male_data['Tissue'].map(dict(zip(merged_df['Tissue'].unique(), palette))), 
           s=25,  # Marker size
           alpha=0.5,  # Opacity
           marker='^',  # Circle marker for male
           label='Male')

# Scatter plot for female data
ax.scatter(xs=female_data.iloc[:, 0], 
           ys=female_data.iloc[:, 1], 
           zs=female_data.iloc[:, 2],  
           c=female_data['Tissue'].map(dict(zip(merged_df['Tissue'].unique(), palette))), 
           s=25,  # Marker size
           alpha=0.5,  # Opacity
           marker='o',  # Square marker for female
           label='Female')

pc1 = my_pdata.uns["pca"]["variance_ratio"][0]
pc2 = my_pdata.uns["pca"]["variance_ratio"][1]
pc3 = my_pdata.uns["pca"]["variance_ratio"][2]
ax.set_xlabel(f"PC1 ({pc1:.2%})")
ax.set_ylabel(f"PC2 ({pc2:.2%})")
ax.set_zlabel(f"PC3 ({pc3:.2%})")  

ax.set_zlim(top=75)

plt.tight_layout()  
plt.legend()  
plt.show()

# %% [markdown]
# ## Extra - analysis of variance explained
# Check how many PCs explain 90, 95% of the variance

# %%
import matplotlib.pyplot as plt
import numpy as np

variance_ratio = my_pdata.uns["pca"]["variance_ratio"]

cumulative_variance = np.cumsum(variance_ratio)

plt.figure(figsize=(8, 4))
plt.plot(range(1, len(variance_ratio) + 1), cumulative_variance, color='red', marker='o', label='Cumulative Variance')

threshold_pc = np.argmax(cumulative_variance >= 0.95) + 1  # +1 because PC indices are 1-based
plt.axvline(x=threshold_pc, color='green', linestyle='--', label=f'95% Variance at PC{threshold_pc}')

threshold_pc_90 = np.argmax(cumulative_variance >= 0.90) + 1  # +1 because PC indices are 1-based
plt.axvline(x=threshold_pc_90, color='blue', linestyle='--', label=f'90% Variance at PC{threshold_pc_90}')

plt.title('Cumulative Variance Explained by Principal Components')
plt.xlabel('Principal Component')
plt.ylabel('Cumulative Variance Explained')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Fig. 1e

# %% [markdown]
# ## Define colors

# %%
tissue_dict = {
    'Adrenal': '#8B4513',        
    'CortexHippocampus': '#F8C471',
    'DiencephalonPituitary': '#27AE60',  
    'Gastrocnemius': '#FF69B4',        
    'GonadsFemale': '#2FE3E5',       
    'GonadsMale': '#00B7B8',
    'Heart': '#AF7AC5',       
    'Kidney': '#CF1E1A',        
    'Liver': '#F15922',            
}

sex_dict = {
    'Female': 'hotpink',
    'Male': 'dodgerblue',  
    
}


geno_dict = {
    '129S1J': '#DA9CC1',  
    'AJ': '#F4C245',             
    'B6J': '#C0BFBF',               
    'CASTJ': '#55AF5B',  
    'NODJ': '#4F6EAF',        
    'NZOJ': '#52A5DB',              
    'PWKJ': '#D83026',        
    'WSBJ': '#683C91'   
}

# %% [markdown]
# ## Long function
# Modified from decoupler https://github.com/saezlab/decoupler-py/blob/3dde7ee3804ef5d5d3bb88a97c212bb5aace4ffb/decoupler/plotting.py#L1535

# %%
def my_plot_associations(data, 
                         uns_key, 
                         associations=None, 
                         cols=None, 
                         obs_annotation_cols=None, 
                         obsm_key=None, use_X=False,
                         layer=None, stat_col='p_adj', 
                         titles=['Scores', 'Stats'], 
                         sign_thr=0.01, n_factors=10,
                         cmap_stats='Purples', cmap_scores='BrBG', 
                         figsize=(5, 5), dpi=100):
    
    
    stats = data.uns[uns_key]
    stats.replace(0, np.finfo(float).eps, inplace=True)
    
    column_name = "PC"
    columns = ['{0}{1}'.format(column_name, 1 + x) for x in range(data.obsm[obsm_key].shape[1])]
    acts = pd.DataFrame(data.obsm[obsm_key],index=data.obs.index,columns=columns)
    
    tissue_order = ['CortexHippocampus',
                     'DiencephalonPituitary',
                     'Heart',
                     'GonadsFemale',
                     'Adrenal',
                     'Gastrocnemius',
                     'Kidney',
                     'Liver',
                     'GonadsMale',
                     ]
    genotype_order = ["AJ", "B6J", "129S1J", "NODJ", "NZOJ", "CASTJ", "PWKJ", "WSBJ"]

    tissue_order_map = {tissue: i for i, tissue in enumerate(tissue_order)}
    genotype_order_map = {genotype: i for i, genotype in enumerate(genotype_order)}

    acts['Tissue'] = data.obs['Tissue']  # Ensure Tissue column matches index
    acts['Genotype'] = data.obs['Genotype']
    acts['Sex'] = data.obs['Sex']  # Ensure Sex column is available
    acts['Tissue_Order'] = acts['Tissue'].map(tissue_order_map)
    acts['Genotype_Order'] = acts['Genotype'].map(genotype_order_map)

    def assign_sex_order(row):
        if row['Tissue'] in ['GonadsMale', 'GonadsFemale']:
            return 0 if row['Sex'] == 'Female' else 1  # No alternation for gonads
        else:
            return 0 if row['Sex'] == 'Female' else 1  # Alternate Male/Female elsewhere

    acts['Sex_Order'] = acts.apply(assign_sex_order, axis=1)

    acts_sorted_full = acts.sort_values(by=['Tissue_Order', 'Genotype_Order', 'Sex_Order'])
    acts_sorted = acts_sorted_full.drop(columns=['Tissue_Order', 'Genotype_Order', 'Sex_Order',
                                           'Tissue', 'Genotype', 'Sex'])

    acts = acts_sorted

    col_order = stats['factor'].unique()
    stats = stats.pivot(index='factor', columns='variable', values=stat_col).T.loc[:, col_order]
    stats.index.name = None
    stats.columns.name = None
    stats = -np.log10(stats)

    stats = stats.loc[:, stats.columns[:n_factors]].copy()
    #print(stats)
    
    acts = acts.loc[:, stats.columns].copy()

    h1 = ma.Heatmap(stats, cmap=cmap_stats, width=4, height=1, name="h1")
    h1.add_title(top=titles[1], align="center")
    h1.add_legends()
    #h1.add_dendrogram("left")
    h1.add_right(mp.Labels(stats.index, ))
    sign_msk = stats.values > -np.log10(sign_thr)
    layer = mp.MarkerMesh(sign_msk, marker='*', label="{0} < {1}".format(stat_col, str(sign_thr)))
    h1.add_layer(layer, name='sign')

    acts_sorted_full['Tissue_colors'] = acts_sorted_full['Tissue'].map(tissue_dict)
    acts_sorted_full['Genotype_colors'] = acts_sorted_full['Genotype'].map(geno_dict)
    acts_sorted_full['Sex_colors'] = acts_sorted_full['Sex'].map(sex_dict)

    h2 = ma.Heatmap(acts.values, cmap=cmap_scores, width=0.4, height=4, name="h2")
    h2.add_title(top=titles[0], align="center")
    h2.add_legends()

    variance_ratio = my_pdata.uns["pca"]["variance_ratio"]
    variance_labels = [f"PC{i + 1} ({round(v * 100, 2)}%)" for i, v in enumerate(variance_ratio)]
    h2.add_bottom(mp.Labels(variance_labels[:acts.shape[1]], rotation=90, size=12))  # Ensure correct length

    for cat_col, color_dict in zip(['Tissue', 'Genotype', 'Sex'], [tissue_dict, geno_dict, sex_dict]):
        color_col = cat_col + '_colors'
        cats = acts_sorted_full[cat_col].values  # Original categories
        cat_colors = acts_sorted_full[color_col].values  # Corresponding colors
        cat_colors = mp.Colors(cats, palette=color_dict, label=cat_col)  # Ensure correct legend order
        h2.add_right(cat_colors, pad=0.1, size=0.2)


    c = (h1 / .2 / h2)
    c.add_legends(side="right",
                  stack_by='row', stack_size=2)
    c.render()

    hax = c.get_ax(board_name='h1', ax_name='h1')
    border = Rectangle((0, 0), 1, 1, fill=False, ec=".1", lw=2, transform=hax.transAxes)
    hax.add_artist(border)

    hax = c.get_ax(board_name='h2', ax_name='h2')
    border = Rectangle((0, 0), 1, 1, fill=False, ec=".1", lw=2, transform=hax.transAxes)
    hax.add_artist(border)

    fig = c.figure
    fig.set_figwidth(figsize[0])
    fig.set_figheight(figsize[1])
    fig.set_dpi(300)

# %% [markdown]
# ## Get metadata associations with PCs

# %%
dc.get_metadata_associations(
    my_pdata,
    obs_keys = ['Genotype', 'Sex', 'Tissue'],  # Metadata columns to associate to PCs
    obsm_key='X_pca',  # Where the PCs are stored
    uns_key='pca_anova',  # Where the results are stored
    inplace=True,
)

# %% [markdown]
# ## Plot metadata associations

# %%
my_plot_associations(
    my_pdata,
    uns_key='pca_anova',  # Summary statistics from the anova tests
    obsm_key='X_pca',  # where the PCs are stored
    stat_col='p_adj',  # Which summary statistic to plot
    obs_annotation_cols = ['Tissue','Genotype','Sex', ], # which sample annotations to plot
    titles=['Principal component scores', 'Adjusted -log10(p-value) from ANOVA'],
    figsize=(6, 5),
    n_factors=threshold_pc_90,
)

# %% [markdown]
# ## Legends in correct order

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def create_standalone_legend(color_dict, label, order, location='upper left'):
    ordered_dict = {key: color_dict[key] for key in order if key in color_dict}
    legend_handles = [mpatches.Patch(color=color) for color in ordered_dict.values()]
    legend_labels = list(ordered_dict.keys())  # Legend items in the correct order

    fig, ax = plt.subplots(figsize=(3, 1))
    legend = ax.legend(legend_handles, legend_labels, title=label, loc=location, fontsize=10, title_fontsize=12)
    legend.set_title(label, prop={'weight': 'bold'})  # Make the legend title bold
    ax.axis('off')  
    fig.set_dpi(300)
    plt.savefig(f"../fig1/{label}_legend.png",bbox_inches='tight', dpi = 300)
    plt.show()

tissue_order = ['CortexHippocampus',
                     'DiencephalonPituitary',
                     'Heart',
                     'GonadsFemale',
                     'Adrenal',
                     'Gastrocnemius',
                     'Kidney',
                     'Liver',
                     'GonadsMale',
                     ]
genotype_order = ["AJ", "B6J", "129S1J", "NODJ", "NZOJ", "CASTJ", "PWKJ", "WSBJ"]

create_standalone_legend(tissue_dict, 'Tissue', tissue_order, location='upper left')
create_standalone_legend(geno_dict, 'Genotype', genotype_order, location='upper left')
create_standalone_legend(sex_dict, 'Sex', list(sex_dict.keys()), location='upper left')  # Sex doesn't need specific order

strain_dict = {'Lab': 'darkgrey', 'Wild': '#d3a021'}
create_standalone_legend(strain_dict, 'Strain type', list(strain_dict.keys()), location='upper left')  # Sex doesn't need specific order

# %% [markdown]
# # Fig. 1f

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import matplotlib.pylab as plt
import PyComplexHeatmap as pch

# %% [markdown]
# ## Read in same pseudobulks as before, normalize

# %%
tissues = ["Gastrocnemius", 
           "Heart", 
           "Adrenal", 
           "GonadsFemale",
           "GonadsMale",
           "CortexHippocampus",
           "DiencephalonPituitary",
           "Liver",
           "Kidney"
]

pdata_list = []

for tissue in tissues:
    pdata = sc.read(f'/share/crsp/lab/seyedam/share/igvf_pipeline/IGVF_analysis/cellbender_tissues/pseudobulk/sample_pseudobulk/{tissue}_sample_pseudobulk.h5ad')
    pdata_list.append(pdata)

my_pdata = sc.AnnData.concatenate(*pdata_list, index_unique = None)
sc.pp.normalize_total(my_pdata, target_sum=1e6)
# Out:
# /opt/apps/python/3.8.0/lib/python3.8/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /opt/apps/python/3.8.0/lib/python3.8/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# ...

# %%
expr_mat = my_pdata.transpose().to_df()

# %% [markdown]
# ## Filter for genes of interest and scale

# %%
genes = [
        'Gm16867',
        'Gm35082',
        'Gjb4', 'Gm11975', 
        'Gm14444','Gm8172', 'Gm13328', 'Tas1r1', 'Kcnmb3', 'Rhox3g',
        'Gm40987', 'Gm9725', 'Gm55594', 'Gm17132', 'Cel', 'Gm49273', 'Gm19000', 'Gm48773', 'Ftl1-ps2', 'Gm26820','ENSMUSG00000120877', 'Gm10110', 'Prdm14', 'Gm38246', 'Gm8902', 'Rps17', 
        'Gm9396', 'Gm13727', 'Cwc22', 'Gm37839', 'Gm11851'
]


filtered_df = expr_mat[expr_mat.index.isin(genes)]

expr_mat_scaled = filtered_df.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

data = expr_mat_scaled

# %% [markdown]
# ## Set up heatmap annotation for rows and cols

# %%
df_row_data = {
    'Genotype': ['B6J'] * 1 + ['129S1J'] * 1 + ['NZOJ'] * 2 + ['CASTJ'] * 6 + ['PWKJ'] * 16 + ['WSBJ'] * 5 ,
    'Gene': [
        'Gm16867',
        'Gm35082',
        'Gjb4', 'Gm11975', 
        'Gm14444','Gm8172', 'Gm13328', 'Tas1r1', 'Kcnmb3', 'Rhox3g',
        'Gm40987', 'Gm9725', 'Gm55594', 'Gm17132', 'Cel', 'Gm49273', 'Gm19000', 'Gm48773', 'Ftl1-ps2', 'Gm26820','ENSMUSG00000120877', 'Gm10110', 'Prdm14', 'Gm38246', 'Gm8902', 'Rps17', 
        'Gm9396', 'Gm13727', 'Cwc22', 'Gm37839', 'Gm11851'
    ]
}

df_row = pd.DataFrame(df_row_data)
df_row.index = df_row['Gene']

df_col = my_pdata.obs
df_col.index = df_col['lab_sample_id']


tissue_dict = {
    'CortexHippocampus': '#F8C471',  
    'Heart': '#AF7AC5',             
    'Liver': '#F15922',               
    'DiencephalonPituitary': '#27AE60',  
    'Adrenal': '#8B4513',        
    'Kidney': '#CF1E1A',              
    'Gastrocnemius': '#FF69B4',        
    'GonadsFemale': '#2FE3E5',       
    'GonadsMale': '#00B7B8'     
}

sex_dict = {
    'Male': 'dodgerblue',  
    'Female': 'hotpink'    
}


geno_dict = {
    '129S1J': '#DA9CC1',  
    'AJ': '#F4C245',             
    'B6J': '#C0BFBF',               
    'CASTJ': '#55AF5B',  
    'NODJ': '#4F6EAF',        
    'NZOJ': '#52A5DB',              
    'PWKJ': '#D83026',        
    'WSBJ': '#683C91'   
}


col_ha = pch.HeatmapAnnotation(Sex=pch.anno_simple(df_col['Sex'],colors=sex_dict),
                               Tissue=pch.anno_simple(df_col['Tissue'],colors=tissue_dict),
                               Genotype=pch.anno_simple(df_col['Genotype'],colors=geno_dict),
                               label_kws = {'visible': False},
                               axis=1)
left_ha = pch.HeatmapAnnotation(Genotype=pch.anno_simple(df_row['Genotype'],colors=geno_dict),
                                label_kws = {'visible': False},
                                axis=0)


genotype_categories = ['AJ','B6J','129S1J','NODJ','NZOJ','CASTJ','PWKJ','WSBJ']
tissue_categories = ['CortexHippocampus',
                     'DiencephalonPituitary',
                     'Heart',
                     'GonadsFemale',
                     'Adrenal',
                     'Gastrocnemius',
                     'Kidney',
                     'Liver',
                     'GonadsMale',
                     ]
sex_categories = ['Female', 'Male']

df_col['Genotype'] = pd.Categorical(df_col['Genotype'], categories=genotype_categories, ordered=True)
df_col['Tissue'] = pd.Categorical(df_col['Tissue'], categories=tissue_categories, ordered=True)
df_col['Sex'] = pd.Categorical(df_col['Sex'], categories=sex_categories, ordered=True)

order_criteria = ['Genotype','Tissue', 'Sex']

df_col.sort_values(order_criteria, inplace=True)

# %% [markdown]
# ## Plot heatmap

# %%
plt.figure(figsize=(3.75, 9))
cm = pch.ClusterMapPlotter(data=data.loc[df_row.index.tolist(),df_col.index.tolist()],
                           show_rownames = True, 
                           cmap = "viridis",
                           label = "normalized\nexpression",
                           top_annotation=col_ha, left_annotation=left_ha,
                           row_cluster=False,col_cluster=False)

plt.savefig("../fig1/geno_specific_gene_hmap_all_tissues_pbulk_sample.png",bbox_inches='tight', dpi=300)

plt.show()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 50.65416666666667 mm

# %% [markdown]
# ## Check weights of these genes in PCs

# %%
pc9_weights = pca_loadings.iloc[:, 8]

ascending_rank = pc9_weights.rank(ascending=True, method="min")  # Smallest absolute weight gets rank 1
descending_rank = pc9_weights.rank(ascending=False, method="min")  # Largest absolute weight gets rank 1

gene_ranks = pd.DataFrame({
    "Ascending Rank": ascending_rank.loc[genes],
    "Descending Rank": descending_rank.loc[genes]
})

# %%
my_gene_weights = pc9_weights.loc[genes]

# %%
df_row = df_row.merge(my_gene_weights, left_index=True, right_index=True)

# %%
df_row = df_row.rename(columns={8: 'PC9_weight'})

# %%
left_ha = pch.HeatmapAnnotation(Genotype=pch.anno_simple(df_row['Genotype'],colors=geno_dict),
                                PC9_rank=pch.anno_barplot(df_row['PC9_weight'],
                                                         cmap='jet',
                                                         linewidth=0.1),
                                label_kws = {'visible': False},
                                axis=0)

# %%
plt.figure(figsize=(3.75, 9))
cm = pch.ClusterMapPlotter(data=data.loc[df_row.index.tolist(),df_col.index.tolist()],
                           show_rownames = True, 
                           cmap = "viridis",
                           label = "normalized\nexpression",
                           top_annotation=col_ha, left_annotation=left_ha,
                           row_cluster=False,col_cluster=False)

plt.savefig("../fig1/geno_specific_gene_hmap_all_tissues_pbulk_sample_pc9.png",bbox_inches='tight', dpi=300)

plt.show()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 50.65416666666667 mm
# Incresing ncol

# %% [markdown]
# # Fig. 1g
#
# First run `../scripts/run_pbulk_pydeseq2.sh` on HPC for all tissues, which calls `../scripts/pseudobulk_pydeseq.py`.

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import matplotlib.pylab as plt
import PyComplexHeatmap as pch
import os

# %%
tissues = ["Gastrocnemius", 
           "Heart", 
           "Adrenal", 
           "GonadsFemale",
           "GonadsMale",
           "CortexHippocampus",
           "DiencephalonPituitary",
           "Liver",
           "Kidney"
]

# %%
lfc_cutoff = 1
padj_cutoff = 0.01

# %% [markdown]
# ## Filter DEG results for comparisons with B6J only

# %%
# filtered_dfs = []

# for tissue in tissues:
#     print(f'Reading {tissue}..')
#     tissue_path = f"/share/crsp/lab/seyedam/share/igvf_pipeline/figures/degs/{tissue}/results_de_analysis.csv"
    
#     if os.path.exists(tissue_path):  # Ensure the file exists
#         df_genes = pd.read_csv(tissue_path, index_col=0)
#         df_genes.reset_index(inplace=True)
        
#         df_filtered = df_genes[(df_genes['log2FoldChange'].abs() >= lfc_cutoff) & (df_genes['padj'] <= padj_cutoff)]

#         # Append the filtered dataframe to the list
#         filtered_dfs.append(df_filtered)
#     else:
#         print(f"File not found for tissue: {tissue}")

# df_filtered = pd.concat(filtered_dfs, ignore_index=True)
# df_filtered.to_csv('/share/crsp/lab/seyedam/share/igvf_pipeline/figures/specificity/sig_degs_all_tissues.csv')

# deg_df_b6j = df_filtered[df_filtered['comparison'].str.contains('B6J')]
# deg_df_b6j['genotype'] = deg_df_b6j['comparison'].str.extract(r'Genotype_(?!B6J)(\S+)_vs_B6J|Genotype_B6J_vs_(\S+)').bfill(axis=1).iloc[:, 0]
# deg_df_b6j.to_csv('/share/crsp/lab/seyedam/share/igvf_pipeline/figures/specificity/sig_degs_all_tissues_b6j.csv')

# %% [markdown]
# ## Read in DEG results

# %%
geno_degs = pd.read_csv('/share/crsp/lab/seyedam/share/igvf_pipeline/figures/specificity/sig_degs_all_tissues_b6j.csv', index_col = 0)
geno_degs = geno_degs[['gene_name', 'celltype', 'genotype', 'tissue']].drop_duplicates()

# %%
# Group by genotype and tissue
gene_counts = geno_degs.groupby(['genotype', 'tissue'])['gene_name'].nunique().unstack(fill_value=0)
gene_counts=gene_counts.transpose()

# %%
tissue_dict = {
    'CortexHippocampus': '#F8C471',  
    'Heart': '#AF7AC5',             
    'Liver': '#F15922',               
    'DiencephalonPituitary': '#27AE60',  
    'Adrenal': '#8B4513',        
    'Kidney': '#CF1E1A',              
    'Gastrocnemius': '#FF69B4',        
    'GonadsFemale': '#2FE3E5',       
    'GonadsMale': '#00B7B8'     
}

geno_dict = {
    '129S1J': '#DA9CC1',  
    'AJ': '#F4C245',             
    'B6J': '#C0BFBF',               
    'CASTJ': '#55AF5B',  
    'NODJ': '#4F6EAF',        
    'NZOJ': '#52A5DB',              
    'PWKJ': '#D83026',        
    'WSBJ': '#683C91'   
}

strain_dict = {'Lab': 'darkgrey', 'Wild': '#d3a021'}

genos = geno_degs['genotype'].unique().tolist()
df_col = pd.DataFrame({
    "Genotype": genos, 
    "Strain type": ["Wild" if x in ["CASTJ","PWKJ","WSBJ"] else "Lab" for x in genos]
})


genotype_categories = ['AJ','B6J','129S1J','NODJ','NZOJ','CASTJ','PWKJ','WSBJ']
df_col['Genotype'] = pd.Categorical(df_col['Genotype'], categories=genotype_categories, ordered=True)
df_col.sort_values(['Genotype'], inplace=True)
df_col = df_col.set_index("Genotype", drop=False)

tissue_categories = ['CortexHippocampus',
                     'DiencephalonPituitary',
                     'Heart',
                     'GonadsFemale',
                     'Adrenal',
                     'Gastrocnemius',
                     'Kidney',
                     'Liver',
                     'GonadsMale',
                     ]

df_row = geno_degs[['tissue']].drop_duplicates()
df_row['tissue'] = pd.Categorical(df_row['tissue'], categories=tissue_categories, ordered=True)
df_row.sort_values(['tissue'], inplace=True)
df_row = df_row.set_index("tissue", drop=False)

col_ha = pch.HeatmapAnnotation(Genotype=pch.anno_simple(df_col['Genotype'],colors=geno_dict),
                               Type=pch.anno_simple(df_col['Strain type'],colors=strain_dict),
                               label_kws = {'visible': False},
                               axis=1)
left_ha = pch.HeatmapAnnotation(Tissue=pch.anno_simple(df_row['tissue'],colors=tissue_dict),
                                label_kws = {'visible': False},
                                axis=0)

# %% [markdown]
# ## Plot heatmap - raw # DEGs

# %%
plt.figure(figsize=(3, 3))


cm = pch.ClusterMapPlotter(data=gene_counts.loc[df_row.index.tolist(),df_col.index.tolist()],
                           show_rownames = True, 
                           show_colnames = True, 
                           cmap = "magma",
                           label = "# subtype-specific\nDEGs vs. B6J",
                           top_annotation=col_ha, 
                           left_annotation=left_ha,
                           row_cluster=False,
                           col_cluster=False,
                           vmin = 0,
                           vmax = 13000,
                           yticklabels_kws={'labelsize': 14},
                           xticklabels_kws={'labelsize': 14} 
                          )
plt.savefig(f"../fig1/geno_degs_tissue_level_hmap.png", 
            dpi=300, bbox_inches="tight", format="png")

plt.show()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 50.65416666666667 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %% [markdown]
# ## Plot heatmap - percent genes DE

# %%
import decoupler as dc

# %%
expr_cutoff = 0.5

# %%
expressed_gene_stats = []

for tissue in tissues:
    print(f"Processing {tissue}")

    # Load pseudobulk expression
    pdata = sc.read_h5ad(f"/share/crsp/lab/seyedam/share/igvf_pipeline/IGVF_analysis/cellbender_tissues/pseudobulk/{tissue}_pseudobulk.h5ad")

    # Ensure 'subtype' and 'Genotype' are strings before concatenating
    pdata.obs['subtype'] = pdata.obs['subtype'].astype(str)
    pdata.obs['Genotype'] = pdata.obs['Genotype'].astype(str)
    
    # Create combined column
    pdata.obs['subtype_genotype'] = pdata.obs['subtype'] + "_" + pdata.obs['Genotype']

    # Compute pseudobulk expression
    pdata2 = dc.get_pseudobulk(
        pdata, 
        sample_col="subtype_genotype",  
        groups_col=None,
        mode='mean', 
        skip_checks=True, 
        min_cells=0, 
        min_counts=0
    )
    expr_df = pdata2.to_df().transpose()  # Genes as rows, celltype-genotype as columns

    # Get list of expressed genes per celltype-genotype
    expressed_genes = expr_df > expr_cutoff  

    # Create a long-form DataFrame of expressed genes
    expressed_gene_list = (
        expressed_genes
        .stack()
        .reset_index()
        .rename(columns={'level_0': 'gene_name', 'level_1': 'celltype_genotype', 0: 'expressed'})
    )

    # Keep only expressed genes
    expressed_gene_list = expressed_gene_list[expressed_gene_list['expressed']].drop(columns=['expressed'])

    # Split 'celltype_genotype' into separate columns
    expressed_gene_list[['celltype', 'genotype']] = expressed_gene_list['celltype_genotype'].str.split('_', n=1, expand=True)

    # Add tissue column
    expressed_gene_list['tissue'] = tissue

    expressed_gene_stats.append(expressed_gene_list)

# Combine results across all tissues
expressed_genes_df = pd.concat(expressed_gene_stats, ignore_index=True)
# Out:
# Processing Gastrocnemius
# Processing Heart
# Processing Adrenal
# Processing GonadsFemale
# Processing GonadsMale
# Processing CortexHippocampus
# Processing DiencephalonPituitary
# Processing Liver
# Processing Kidney

# %%
geno_degs['genotype_DEG'] = geno_degs['genotype']

# %%
merged_df = expressed_genes_df.merge(
    geno_degs,
    on=['gene_name', 'celltype', 'genotype', 'tissue'],
    how='left'
)

# %%
merged_df['genotype_DEG'] = merged_df['genotype_DEG'].fillna('Not_DE')

# %%
merged_df_filt = merged_df[merged_df['genotype'] != 'B6J']

# %%
de_percent_df = (
    merged_df_filt.groupby(['tissue', 'genotype'])['genotype_DEG']
    .apply(lambda x: (x != 'Not_DE').mean() * 100)  # Percent DE
    .reset_index(name='percent_DE')
)

# %%
heatmap_data = de_percent_df.pivot(index='tissue', columns='genotype', values='percent_DE')

# %%
plt.figure(figsize=(3, 3))


cm = pch.ClusterMapPlotter(data=heatmap_data.loc[df_row.index.tolist(),df_col.index.tolist()],
                           show_rownames = True, 
                           show_colnames = True, 
                           cmap = "magma",
                           label = "% DEGs",
                           top_annotation=col_ha, 
                           left_annotation=left_ha,
                           row_cluster=False,
                           col_cluster=False,
                           vmin = 0,
                           vmax = 12,
                           yticklabels_kws={'labelsize': 14},
                           xticklabels_kws={'labelsize': 14} 
                          )
plt.savefig(f"../fig1/geno_degs_tissue_level_hmap_percent_expr_{expr_cutoff}.png", 
            dpi=300, bbox_inches="tight", format="png")

plt.show()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 50.65416666666667 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %% [markdown]
# ## Extra -- Upset plot of all DEGs across tissues and genotypes

# %%
merged_df_filt_degs = merged_df_filt[merged_df_filt['genotype_DEG'] != 'Not_DE']
merged_df_filt_degs = merged_df_filt_degs[['gene_name', 'tissue']].drop_duplicates()

# %%
import pandas as pd
from collections import defaultdict
from upsetplot import UpSet
import matplotlib.pyplot as plt

tissue_gene_sets = defaultdict(set)
for _, row in merged_df_filt_degs.iterrows():
    tissue_gene_sets[row['tissue']].add(row['gene_name'])

# %%
# Convert to a binary matrix for UpSet plot
all_genes = set(merged_df_filt_degs['gene_name'])
binary_matrix = {tissue: [gene in genes for gene in all_genes] for tissue, genes in tissue_gene_sets.items()}
upset_df = pd.DataFrame(binary_matrix, index=list(all_genes))

# %%
upset_df_gm = upset_df[(upset_df["GonadsMale"]) & (upset_df.drop(columns=["GonadsMale"]) == False).all(axis=1)]

# %%
# Get the list of gene names from your dataframe
gene_names = upset_df_gm.index.tolist()
n_gm_genes = len(gene_names)

# %%
# Load the GTF file
gtf_path = '/share/crsp/lab/seyedam/share/igvf_splitseq/ref/gencode.vM32.chr_patch_hapl_scaff.annotation.gtf'

# Read the GTF file using pandas
gtf_df = pd.read_csv(gtf_path, sep='\t', comment='#', header=None)

# Extract relevant columns: gene_name and gene_type (gene_type is in the 9th column as 'gene_biotype')
gtf_df['gene_name'] = gtf_df[8].str.extract('gene_name "([^"]+)"')
gtf_df['gene_type'] = gtf_df[8].str.extract('gene_type "([^"]+)"')

# %%
# Filter to only keep unique gene_name and their gene_type
gtf_genes = gtf_df[['gene_name', 'gene_type']].drop_duplicates()

# %%
my_df = pd.DataFrame(gene_names, columns=['gene_name'])

# %%
merged_genes = my_df.merge(gtf_genes, on='gene_name', how='left')

# %%
pc = merged_genes[merged_genes['gene_type'] == 'protein_coding']
lnc = merged_genes[merged_genes['gene_type'].isin(['lncRNA']) | 
                   merged_genes['gene_type'].str.contains('pseudogene', na=False)]

n_pcs = len(pc['gene_name'].unique().tolist())
n_lncs = len(lnc['gene_name'].unique().tolist())

print(n_pcs/n_gm_genes)
print(n_lncs/n_gm_genes)

gene_names = pc['gene_name'].tolist()

# Calculate the percentages for different gene name patterns
total_genes = len(gene_names)

# Conditions for different gene name patterns
rik_genes = [gene for gene in gene_names if gene.endswith('Rik')]
ensmusg_genes = [gene for gene in gene_names if gene.startswith('ENSMUSG')]
gm_genes = [gene for gene in gene_names if gene.startswith('Gm') and gene[2:].isdigit()]
or_genes = [gene for gene in gene_names if gene.startswith('Or')]
vmn_genes = [gene for gene in gene_names if gene.startswith('Vmn')]
defb_genes = [gene for gene in gene_names if gene.startswith('Defb')]
tmem_genes = [gene for gene in gene_names if gene.startswith('Tmem')]

# Calculate the percentage for each category
rik_percent = (len(rik_genes) / total_genes) * 100
ensmusg_percent = (len(ensmusg_genes) / total_genes) * 100
gm_percent = (len(gm_genes) / total_genes) * 100
or_percent = (len(or_genes) / total_genes) * 100
vmn_percent = (len(vmn_genes) / total_genes) * 100
defb_percent = (len(defb_genes) / total_genes) * 100
tmem_percent = (len(tmem_genes) / total_genes) * 100

# Print the results
print(f"Percentage of genes ending in 'Rik': {rik_percent:.2f}%")
print(f"Percentage of genes starting with 'ENSMUSG': {ensmusg_percent:.2f}%")
print(f"Percentage of genes starting with 'Gm': {gm_percent:.2f}%")
print(f"Percentage of genes starting with 'Or': {or_percent:.2f}%")
print(f"Percentage of genes starting with 'Vmn': {vmn_percent:.2f}%")
print(f"Percentage of genes starting with 'Defb': {defb_percent:.2f}%")
print(f"Percentage of genes starting with 'Tmem': {tmem_percent:.2f}%")
# Out:
# 0.4028978139298424
# 0.5366039654295882
# Percentage of genes ending in 'Rik': 2.33%
# Percentage of genes starting with 'ENSMUSG': 0.32%
# Percentage of genes starting with 'Gm': 14.01%
# Percentage of genes starting with 'Or': 18.86%
# Percentage of genes starting with 'Vmn': 4.73%
# Percentage of genes starting with 'Defb': 1.01%
# Percentage of genes starting with 'Tmem': 0.95%

# %%
from upsetplot import UpSet, from_indicators

# %%
upset_data = from_indicators(upset_df.columns, upset_df)

upset = UpSet(upset_data, sort_by = 'cardinality', 
              sort_categories_by = '-cardinality',
              subset_size='count',
              max_subset_rank=25,
              show_counts = True
             )
upset.plot()
plt.savefig(f"../fig1/deg_tissue_upset_plot.png", dpi=300, bbox_inches="tight")  
plt.savefig(f"../fig1/deg_tissue_upset_plot.pdf", dpi=300, bbox_inches="tight") 

plt.show()

# %%
merged_df_filt_degs = merged_df_filt[merged_df_filt['genotype_DEG'] != 'Not_DE']
merged_df_filt_degs = merged_df_filt_degs[['gene_name', 'genotype']].drop_duplicates()

# %%
geno_gene_sets = defaultdict(set)
for _, row in merged_df_filt_degs.iterrows():
    geno_gene_sets[row['genotype']].add(row['gene_name'])

# %%
# Convert to a binary matrix for UpSet plot
all_genes = set(merged_df_filt_degs['gene_name'])
binary_matrix = {tissue: [gene in genes for gene in all_genes] for tissue, genes in geno_gene_sets.items()}
upset_df = pd.DataFrame(binary_matrix, index=list(all_genes))

# %%
upset_data = from_indicators(upset_df.columns, upset_df)

upset = UpSet(upset_data, sort_by = 'cardinality', 
              sort_categories_by = '-cardinality',
              subset_size='count',
              max_subset_rank=25,
              show_counts = True
             )
upset.plot()
plt.savefig(f"../fig1/deg_geno_upset_plot.png", dpi=300, bbox_inches="tight")  
plt.savefig(f"../fig1/deg_geno_upset_plot.pdf", dpi=300, bbox_inches="tight") 

plt.show()

# %% [markdown]
# ### Upregulated/downregulated upsets

# %%
geno_degs = pd.read_csv('/share/crsp/lab/seyedam/share/igvf_pipeline/figures/specificity/sig_degs_all_tissues_b6j.csv', index_col = 0)
geno_degs['genotype_DEG'] = geno_degs['genotype']

geno_degs_up = geno_degs[geno_degs['log2FoldChange']<0]
geno_degs_up = geno_degs_up[['gene_name', 'celltype', 'genotype', 'tissue']].drop_duplicates()

geno_degs_down = geno_degs[geno_degs['log2FoldChange']>0]
geno_degs_down = geno_degs_down[['gene_name', 'celltype', 'genotype', 'tissue']].drop_duplicates()

merged_df_up = geno_degs_up.merge(
    expressed_genes_df,
    on=['gene_name', 'celltype', 'genotype', 'tissue'],
    how='left'
)


merged_df_down = geno_degs_down.merge(
    expressed_genes_df,
    on=['gene_name', 'celltype', 'genotype', 'tissue'],
    how='left'
)

# %%
merged_df_up_tiss = merged_df_up[['gene_name', 'tissue']].drop_duplicates()
merged_df_down_tiss = merged_df_down[['gene_name', 'tissue']].drop_duplicates()

# %%
# Convert to a binary matrix for UpSet plot
all_genes = set(merged_df_up_tiss['gene_name'])
binary_matrix = {tissue: [gene in genes for gene in all_genes] for tissue, genes in tissue_gene_sets.items()}
upset_df_up = pd.DataFrame(binary_matrix, index=list(all_genes))

all_genes = set(merged_df_down_tiss['gene_name'])
binary_matrix = {tissue: [gene in genes for gene in all_genes] for tissue, genes in tissue_gene_sets.items()}
upset_df_down = pd.DataFrame(binary_matrix, index=list(all_genes))

# %%
upset_data_up = from_indicators(upset_df_up.columns, upset_df_up)

upset = UpSet(upset_data_up, sort_by = 'cardinality', 
              sort_categories_by = '-cardinality',
              subset_size='count',
              max_subset_rank=25,
              show_counts = True
             )
upset.plot()

plt.show()

# %%
upset_data_down = from_indicators(upset_df_down.columns, upset_df_down)

upset = UpSet(upset_data_down, sort_by = 'cardinality', 
              sort_categories_by = '-cardinality',
              subset_size='count',
              max_subset_rank=25,
              show_counts = True
             )
upset.plot()

plt.show()

# %% [markdown]
# ## Extra -- heatmap of all comparisons

# %%
deg_df = pd.read_csv('/share/crsp/lab/seyedam/share/igvf_pipeline/figures/specificity/sig_degs_all_tissues.csv', index_col = 0)
deg_df["comparison"] = deg_df["comparison"].str.replace("^Genotype_", "", regex=True)

deg_df["adjusted_comparison"] = deg_df.apply(
    lambda row: row["comparison"] if row["log2FoldChange"] > 0 else "_vs_".join(reversed(row["comparison"].split("_vs_"))),
    axis=1
)

comparison_order = [
    'AJ_vs_B6J', 'AJ_vs_129S1J', 'AJ_vs_NODJ', 'AJ_vs_NZOJ','AJ_vs_CASTJ', 'AJ_vs_PWKJ', 'AJ_vs_WSBJ', 
    'B6J_vs_AJ','B6J_vs_129S1J', 'B6J_vs_NODJ', 'B6J_vs_NZOJ', 'B6J_vs_CASTJ', 'B6J_vs_PWKJ', 'B6J_vs_WSBJ', 
    '129S1J_vs_AJ','129S1J_vs_B6J', '129S1J_vs_NODJ', '129S1J_vs_NZOJ', '129S1J_vs_CASTJ', '129S1J_vs_PWKJ', '129S1J_vs_WSBJ', 
    'NODJ_vs_AJ','NODJ_vs_B6J', 'NODJ_vs_129S1J', 'NODJ_vs_NZOJ', 'NODJ_vs_CASTJ', 'NODJ_vs_PWKJ', 'NODJ_vs_WSBJ',
    'NZOJ_vs_AJ', 'NZOJ_vs_B6J', 'NZOJ_vs_129S1J', 'NZOJ_vs_NODJ',  'NZOJ_vs_CASTJ', 'NZOJ_vs_PWKJ','NZOJ_vs_WSBJ', 
    'CASTJ_vs_AJ','CASTJ_vs_B6J', 'CASTJ_vs_129S1J', 'CASTJ_vs_NODJ', 'CASTJ_vs_NZOJ', 'CASTJ_vs_PWKJ','CASTJ_vs_WSBJ', 
    'PWKJ_vs_AJ', 'PWKJ_vs_B6J', 'PWKJ_vs_129S1J', 'PWKJ_vs_NODJ', 'PWKJ_vs_NZOJ',  'PWKJ_vs_CASTJ', 'PWKJ_vs_WSBJ',
    'WSBJ_vs_AJ', 'WSBJ_vs_B6J', 'WSBJ_vs_129S1J', 'WSBJ_vs_NODJ', 'WSBJ_vs_NZOJ',  'WSBJ_vs_CASTJ', 'WSBJ_vs_PWKJ',

]

result = deg_df.groupby(["tissue", "adjusted_comparison"])["gene_name"].nunique().unstack(fill_value=0).reindex(columns=comparison_order, fill_value=0).stack().reset_index()
result.columns = ["tissue", "comparison", "unique_gene_count"]

# %%
df_pivot = result.pivot(index="tissue", columns="comparison", values="unique_gene_count").fillna(0)

# %%
column_names = df_pivot.columns

# Initialize lists to store genotype information
genotype1 = []
genotype2 = []

# Extract genotypes from the column names
for col in column_names:
    g1, g2 = col.split('_vs_')
    genotype1.append(g1)
    genotype2.append(g2)

# Create the supporting DataFrame df_col
df_col = pd.DataFrame({
    'Genotype1': genotype1,
    'Genotype2': genotype2
}, index=column_names)


wild_strains = ['WSBJ', 'CASTJ', 'PWKJ']

# Create the 'Strain_type' column based on Genotype1 and Genotype2
df_col['Strain_type'] = df_col.apply(
    lambda row: 'Wild' if row['Genotype1'] in wild_strains or row['Genotype2'] in wild_strains else 'Lab', 
    axis=1
)

# %%
col_ha = pch.HeatmapAnnotation(Genotype1=pch.anno_simple(df_col['Genotype1'],colors=geno_dict),
                               Genotype2=pch.anno_simple(df_col['Genotype2'],colors=geno_dict),
                               Strain_type=pch.anno_simple(df_col['Strain_type'],colors=strain_dict),
                               verbose=1,axis=1,
                               label_kws = {'visible': False},
                              )
comparison_order_reversed = comparison_order[::-1]

# %%
df_pivot_reordered = df_pivot[comparison_order]
desired_order = [
    "CortexHippocampus", 
    "DiencephalonPituitary", 
    "Heart",
    "GonadsFemale",     
    "Adrenal", 
    "Gastrocnemius", 
    "Kidney", 
    "Liver", 
    "GonadsMale", 
    
]

# Ensure the index is in the desired order
df_pivot_reordered.index = pd.Categorical(df_pivot_reordered.index, 
                                          categories=desired_order, 
                                          ordered=True)

# Sort the DataFrame by the new categorical index
df_pivot_reordered = df_pivot_reordered.sort_index()

# %%
plt.figure(figsize=(17, 6))
cm = pch.ClusterMapPlotter(data=df_pivot_reordered,
                           show_rownames = True, 
                           show_colnames = True, 
                           cmap = "magma",
                           label = "# upregulated genes",
                           top_annotation=col_ha, 
                           yticklabels_kws={'labelsize': 16},
                           row_cluster=False,col_cluster=False,
                           vmin=0, 
                           vmax=8000
                          )

plt.savefig("../fig1/geno_specific_gene_hmap_all_tissues_pbulk_sample.png",bbox_inches='tight',dpi=300)
plt.show()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 27.72361111111111 mm
# Incresing ncol

# %% [markdown]
# # Fig. 1h
#
# First run `../scripts/run_subclustering_analysis_ryan.sh` on HPC for all tissues, which calls `../scripts/subclust_chi_fixed_ryan.py`.

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import matplotlib.pylab as plt
import PyComplexHeatmap as pch

# %%
res = 0.2
prop = 0.75

# %%
tissues = [
           "CortexHippocampus",
           "DiencephalonPituitary",
           "Heart", 
           "GonadsFemale",
           "Adrenal", 
           "Gastrocnemius", 
           "Liver",
           "Kidney",
           "GonadsMale",
]

# %% [markdown]
# ## Read in clustering results

# %%
all_tissues_data = []

for tissue in tissues:
    # Read and filter the data
    chisq_results = pd.read_csv(
        f"/share/crsp/lab/seyedam/share/igvf_pipeline/figures/subclustering_subtypes/{tissue}/{tissue}_proportion_results_fixed_prop{prop}_res{res}_fixed_hvgs_1217.csv", 
        index_col=0
    )
    chisq_results = chisq_results[chisq_results['subtype'] != 'low quality']

    # Group and calculate percentages
    grouped_df = chisq_results.groupby(['Genotype', 'tissue']).agg({
        'ncells_specific_cluster': 'sum',
        'ncells_total': 'sum'
    }).reset_index()
    grouped_df['percentage_cells'] = (grouped_df['ncells_specific_cluster'] / grouped_df['ncells_total']) * 100

    # Append to the list
    all_tissues_data.append(grouped_df)

# %%
merged_df = pd.concat(all_tissues_data)

plot_df = merged_df.pivot_table(
    index=['tissue'], 
    columns='Genotype',         
    values='percentage_cells',   
    fill_value=0)

# %%
plt.figure(figsize=(3.1, 3))

df_row = pd.DataFrame(merged_df['tissue'].drop_duplicates())
df_row.index = df_row['tissue']

left_ha = pch.HeatmapAnnotation(Tissue=pch.anno_simple(df_row['tissue'],colors=tissue_dict),
                                label_kws = {'visible': False},
                                axis=0)

genos = merged_df['Genotype'].unique().tolist()
df_col = pd.DataFrame({
    "Genotype": genos, 
    "Strain type": ["Wild" if x in ["CASTJ","PWKJ","WSBJ"] else "Lab" for x in genos]
})

genotype_categories = ['AJ','B6J','129S1J','NODJ','NZOJ','CASTJ','PWKJ','WSBJ']
df_col['Genotype'] = pd.Categorical(df_col['Genotype'], categories=genotype_categories, ordered=True)
df_col.sort_values(['Genotype'], inplace=True)
df_col = df_col.set_index("Genotype", drop=False)


col_ha = pch.HeatmapAnnotation(Genotype=pch.anno_simple(df_col['Genotype'],colors=geno_dict),
                               Type=pch.anno_simple(df_col['Strain type'],colors=strain_dict),
                               label_kws = {'visible': False},
                               axis=1)

cm = pch.ClusterMapPlotter(data=plot_df.loc[df_row.index.tolist(),df_col.index.tolist()],
                           show_rownames = True, 
                           show_colnames = True, 
                           cmap = "mako",
                           label = "% nuclei clustered\nby genotype",
                           top_annotation=col_ha, 
                           left_annotation=left_ha,
                           row_cluster=False,
                           col_cluster=False,
                           vmin = 0,
                           vmax = 100,
                           yticklabels_kws={'labelsize': 14},
                           xticklabels_kws={'labelsize': 14} 
                          )

plt.savefig(f"../fig1/subclustering_tissue_level_hmap.png", 
            dpi=300, bbox_inches="tight", format="png")


plt.show()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 50.65416666666667 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..
